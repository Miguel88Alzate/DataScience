# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
#
# * Add comments to code cells
# * Create markdown cells
# * Add ordered and unordered lists to markdowns cells
# * Format content of markdown cells with heading styles

# %% [markdown]
# Some of the popular languages that Data Scientists use are:

# %% [markdown]
# 1. Python
# 2. R
# 3. C++
# 4. Java
# 5. SQL
# 6. Scala
# 7. Julia
# 8. JavaScript
# 9. Php
# 10. Go
# 11. Ruby
# 12. Visual Basic

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:

# %% [markdown]
# 1. TensorFlow
# 2. Pandas
# 3. Numpy
# 4. Scikit-learn
# 5. Matplotlib
# 6. Seaborn
# 7. Ggplot2
# 8. Vegas
# 9. Big DL
# 10. Apache Sparl
# 11. Keras
# 12. PyTorch

# %% [markdown]
# | Data Science Tools |
# |:--------:|
# |  Jupyter Notebooks   |
# |  RStudio   |
# |  Zeppelin   |
# |  Anaconda   |
# |  Sypder   |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# $\hat{Y} = \hat{\beta}_{0} + \sum \limits _{j=1} ^{p} X_{j}\hat{\beta}_{j} $

# %%
#This a simple arithmetic 
#expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %%
#This will convert 200 minutes to hours by diving by 60

minutes = 200

hours = minutes/60

print("Here is the rounded conversion",round(hours,2),'hours')
# Out:
# Here is the rounded conversion 3.33 hours

# %% [markdown]
# ## Author
# Miguel Alzate
